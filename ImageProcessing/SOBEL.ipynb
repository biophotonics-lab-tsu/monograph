# %% [markdown]
# ### №1 Section for importing main libraries and defining main function

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import statistics
from scipy import ndimage, misc
from skimage.transform import rescale
from PIL import Image
from skimage.morphology import erosion, dilation, opening, closing, white_tophat
from skimage.morphology import disk, skeletonize

def plot2figs(image1, image2, title):
    plt.subplot(1,2,1)
    plt.axis('off')
    plt.imshow(image1, cmap=plt.cm.gray)
    plt.title('Original image')
    plt.subplot(1,2,2)
    plt.axis('off')
    plt.imshow(image2, cmap=plt.cm.gray)
    plt.title(title)
    plt.show()

# %% [markdown]
# ### №2 Section for loading image

# %%
image = Image.open(os.path.join('../bin_data', 'collagen.png'))

# %% [markdown]
# ### №3 Section for SOBEL visualization

# %%
rescaled = rescale(np.asarray(image), 0.25)
sobel_img = ndimage.sobel(rescaled)
plot2figs(rescaled, sobel_img, 'SOBEL image')
