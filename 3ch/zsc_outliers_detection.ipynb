# %% [markdown]
# ### №1 Section for importing libraries and reading data

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

colors = ['b', 'g', 'r']
markers = ['s', '*', 'o']
work_dir_path = os.path.join(os.getcwd(), 'bin_data')
spectra_path = os.path.join(work_dir_path, 'data.npy')
labels_path = os.path.join(work_dir_path, 'labels.npy')
spectra = np.load(spectra_path)
labels = np.load(labels_path)

# %% [markdown]
# ### №2 Section for visualizing input data

# %%
def plot_spectra(spectra, labels):
    unique_labels = np.unique(labels)

    fig = plt.figure(figsize=(15, 7), dpi=100)
    plt.ylabel('Absorption', fontsize=10)
    plt.xlabel('Wavenumber / frequency / wavelength', fontsize=10)
    plt.xticks(fontsize=8)
    plt.yticks(fontsize=8)
    c = 1
    for label in unique_labels:
        label_indices = (labels[:] == label)
        label_spectra = spectra[label_indices]
        
        for spectrum in label_spectra:
            plt.plot(range(0, len(spectrum)), spectrum, color=colors[len(colors) % c], label=label)
        c += 1

    legend_handles, legend_labels = plt.gca().get_legend_handles_labels()
    handle_by_label = dict(zip(legend_labels, legend_handles))
    plt.legend(handle_by_label.values(), handle_by_label.keys()) 
    plt.show()

    return

plot_spectra(spectra, labels)

# %% [markdown]
# ### №3 Section for feature selection by Isolation Forest

# %%
threshold = 3
#We search for outliers in the first class only
for component_num in range(0,np.size(spectra[0])):
    mean = np.mean(spectra[:50,component_num]) 
    std = np.std(spectra[:50,component_num]) 
    outlier =[] 
    for i,spectrum in enumerate(spectra[:50]): 
        z = (spectrum[component_num]-mean)/std 
        if (z > threshold): 
            outlier.append(i) 
    if len(outlier)>0:
        print('Outlier component #', component_num)
# Out:
# r component # 4804
# Outlier component # 4805
# Outlier component # 4806
# Outlier component # 4807
# Outlier component # 4808
# Outlier component # 4809
# Outlier component # 4810
# Outlier component # 4811
# Outlier component # 4812
# Outlier component # 4813
# Outlier component # 4814
# Outlier component # 4815
# Outlier component # 4816
# Outlier component # 4817
# Outlier component # 4818
# Outlier component # 4819
# Outlier component # 4820
# Outlier component # 4821
# Outlier component # 4822
# Outlier component # 4823
# Outlier component # 4824
# Outlier component # 4826
# Outlier component # 4827
# Outlier component # 4828
# Outlier component # 4829
# Outlier component # 4830
# Outlier component # 4831
# Outlier component # 4832
# Outlier component # 4833
# Outlier component # 4834
# Outlier component # 4835
# Outlier component # 4836
# Outlier component # 4837
# Outlier component # 4838
# Outlier component # 4839
# Outlier component # 4840
# Outlier component # 4841
# Outlier component # 4842
# Outlier component # 4843
# Outlier component # 4844
# Outlier component # 4845
# Outlier component # 4846
# Outlier component # 4847
# Outlier component # 4848
# Outlier component # 4849
# Outlier component # 4850
# Outlier component # 4851
# Outlier component # 4852
# Outlier component # 4853
# Outlier component # 4854
# Outlier component # 4855
# Outlier component # 4856
# Outlier component # 4857
# Outlier component # 4858
# Outlier component # 4859
# Outlier component # 4860
# Outlier component # 4861
# Outlier component # 4862
# Outlier component # 4863
# Outlier component # 4864
# Outlier component # 4865
# Outlier component # 4866
# Outlier component # 4867
# Outlier component # 4868
# Outlier component # 4869
# Outlier component # 4870
# Outlier component # 4871
# Outlier component # 4872
# Outlier component # 4873
# Outlier component # 4874
# Outlier component # 4875
# Outlier component # 4876
# Outlier component # 4877
# Outlier component # 4878
# Outlier component # 4879
# Outlier component # 4880
# Outlier component # 4881
# Outlier component # 4882
# Outlier component # 4883
# Outlier component # 4884
# Outlier component # 4885
# Outlier component # 4886
# Outlier component # 4887
# Outlier component # 4888
# Outlier component # 4889
# Outlier component # 4890
# Outlier component # 4891
# Outlier component # 4892
# Outlier component # 4893
# Outlier component # 4894
# Outlier component # 4895
# Outlier component # 4896
# Outlier component # 4897
# Outlier component # 4898
# Outlier component # 4899
# Outlier component # 4900
# Outlier component # 4901
# Outlier component # 4902
# Outlier component # 4903
# Outlier component # 4904
# Outlier component # 4905
# Outlier component # 4906
# Outlier component # 4907
# Outlier component # 4908
# Outlier component # 4909
# Outlier component # 4910
# Outlier component # 4911
# Outlier component # 4912
# Outlier component # 4913
# Outlier component # 4914
# Outlier component # 4915
# Outlier component # 4916
# Outlier component # 4917
# Outlier component # 4918
# Outlier component # 4919
# Outlier component # 4920
# Outlier component # 4921
# Outlier component # 4922
# Outlier component # 4923
# Outlier component # 4924
# Outlier component # 4925
# Outlier component # 4926
# Outlier component # 4927
# Outlier component # 4928
# Outlier component # 4929
# Outlier component # 4930
# Outlier component # 4931
# Outlier component # 4932
# Outlier component # 4933
# Outlier component # 4934
# Outlier component # 4935
# Outlier component # 4936
# Outlier component # 4937
# Outlier component # 4938
# Outlier component # 4939
# Outlier component # 4940
# Outlier component # 4941
# Outlier component # 4942
# Outlier component # 4943
# Outlier component # 4944
# Outlier component # 4945
# Outlier component # 4946
# Outlier component # 4947
# Outlier component # 4948
# Outlier component # 4949
# Outlier component # 4950
# Outlier component # 4951
# Outlier component # 4952
# Outlier component # 4953
# Outlier component # 4954
# Outlier component # 4955
# Outlier component # 4956
# Outlier component # 4957
# Outlier component # 4958
# Outlier component # 4959
# Outlier component # 4960
# Outlier component # 4961
# Outlier component # 4962
# Outlier component # 4963
# Outlier component # 4964
# Outlier component # 4965
# Outlier component # 4966
# Outlier component # 4967
# Outlier component # 4968
# Outlier component # 4969
# Outlier component # 4970
# Outlier component # 4971
# Outlier component # 4972
# Outlier component # 4973
# Outlier component # 4974
# Outlier component # 4975
# Outlier component # 4976
# Outlier component # 4977
# Outlier component # 4978
# Outlier component # 4979
# Outlier component # 4980
# Outlier component # 4981
# Outlier component # 4982
# Outlier component # 4983
# Outlier component # 4984
# Outlier component # 4985
# Outlier component # 4986
# Outlier component # 4987
# Outlier component # 4988
# Outlier component # 4989
# Outlier component # 4990
# Outlier component # 4991
# Outlier component # 4992
# Outlier component # 4993
# Outlier component # 4994
# Outlier component # 4995
# Outlier component # 4997
# Outlier component # 4998
# Outlier component # 4999
# Outlier component # 5000
# Outlier component # 5001
# Outlier component # 5002
# Outlier component # 5003
# Outlier component # 5006
# Outlier component # 5008
# Outlier component # 5009
# Outlier component # 5010
# Outlier component # 5011
# Outlier component # 5012
# Outlier component # 5013
# Outlier component # 5014
# Outlier component # 5015
# Outlier component # 5016
# Outlier component # 5017
# Outlier component # 5018
# Outlier component # 5019
# Outlier component # 5020
# Outlier component # 5021
# Outlier component # 5022
# Outlier component # 5023
# Outlier component # 5024
# Outlier component # 5025
# Outlier component # 5026
# Outlier component # 5027
# Outlier component # 5028
# Outlier component # 5029
# Outlier component # 5030
# Outlier component # 5031
# Outlier component # 5032
# Outlier component # 5033
# Outlier component # 5034
# Outlier component # 5035
# Outlier component # 5036
# Outlier component # 5037
# Outlier component # 5038
# Outlier component # 5039
# Outlier component # 5040
# Outlier component # 5041
# Outlier component # 5042
# Outlier component # 5043
# Outlier component # 5046
# Outlier component # 5047
# Outlier component # 5048
# Outlier component # 5049
# Outlier component # 5050
# Outlier component # 5051
# Outlier component # 5052
# Outlier component # 5057
# Outlier component # 5058
# Outlier component # 5060
# Outlier component # 5061
# Outlier component # 5062
# Outlier component # 5063
# Outlier component # 5069
# Outlier component # 5071
# Outlier component # 5072
# Outlier component # 5073
# Outlier component # 5074
# Outlier component # 5075
# Outlier component # 5076
# Outlier component # 5077
# Outlier component # 5078
# Outlier component # 5080
# Outlier component # 5083
# Outlier component # 5084
# Outlier component # 5085
# Outlier component # 5093
# Outlier component # 5094
# Outlier component # 5095
# Outlier component # 5096
# Outlier component # 5097
# Outlier component # 5098
# Outlier component # 5099
# Outlier component # 5100
# Outlier component # 5101
# Outlier component # 5102
# Outlier component # 5103
# Outlier component # 5104
# Outlier component # 5105
# Outlier component # 5106
# Outlier component # 5107
# Outlier component # 5108
# Outlier component # 5109
# Outlier component # 5110
# Outlier component # 5111
# Outlier component # 5112
# Outlier component # 5113
# Outlier component # 5114
# Outlier component # 5115
# Outlier component # 5116
# Outlier component # 5117
# Outlier component # 5118
# Outlier component # 5119
# Outlier component # 5120
# Outlier component # 5121
# Outlier component # 5122
# Outlier component # 5123
# Outlier component # 5124
# Outlier component # 5125
# Outlier component # 5126
# Outlier component # 5127
# Outlier component # 5128
# Outlier component # 5129
# Outlier component # 5130
# Outlier component # 5131
# Outlier component # 5132
# Outlier component # 5133
# Outlier component # 5134
# Outlier component # 5135
# Outlier component # 5136
# Outlier component # 5137
# Outlier component # 5138
# Outlier component # 5139
# Outlier component # 5140
# Outlier component # 5141
# Outlier component # 5142
# Outlier component # 5143
# Outlier component # 5144
# Outlier component # 5145
# Outlier component # 5146
# Outlier component # 5147
# Outlier component # 5148
# Outlier component # 5149
# Outlier component # 5150
# Outlier component # 5151
# Outlier component # 5152
# Outlier component # 5153
# Outlier component # 5154
# Outlier component # 5155
# Outlier component # 5156
# Outlier component # 5157
# Outlier component # 5158
# Outlier component # 5159
# Outlier component # 5160
# Outlier component # 5161
# Outlier component # 5162
# Outlier component # 5163
# Outlier component # 5164
# Outlier component # 5165
# Outlier component # 5166
# Outlier component # 5167
# Outlier component # 5168
# Outlier component # 5169
# Outlier component # 5170
# Outlier component # 5171
# Outlier component # 5172
# Outlier component # 5173
# Outlier component # 5174
# Outlier component # 5175
# Outlier component # 5176
# Outlier component # 5177
# Outlier component # 5178
# Outlier component # 5179
# Outlier component # 5180
# Outlier component # 5181
# Outlier component # 5182
# Outlier component # 5183
# Outlier component # 5184
# Outlier component # 5185
# Outlier component # 5186
# Outlier component # 5187
# Outlier component # 5188
# Outlier component # 5189
# Outlier component # 5190
# Outlier component # 5191
# Outlier component # 5192
# Outlier component # 5193
# Outlier component # 5194
# Outlier component # 5195
# Outlier component # 5196
# Outlier component # 5197
# Outlier component # 5198
# Outlier component # 5199
# Outlier component # 5200
# Outlier component # 5201
# Outlier component # 5202
# Outlier component # 5203
# Outlier component # 5204
# Outlier component # 5205
# Outlier component # 5206
# Outlier component # 5207
# Outlier component # 5208
# Outlier component # 5209
# Outlier component # 5210
# Outlier component # 5211
# Outlier component # 5212
# Outlier component # 5213
# Outlier component # 5214
# Outlier component # 5215
# Outlier component # 5216
# Outlier component # 5217
# Outlier component # 5218
# Outlier component # 5219
# Outlier component # 5220
# Outlier component # 5221
# Outlier component # 5222
# Outlier component # 5223
# Outlier component # 5224
# Outlier component # 5225
# Outlier component # 5226
# Outlier component # 5227
# Outlier component # 5228
# Outlier component # 5229
# Outlier component # 5230
# Outlier component # 5231
# Outlier component # 5232
# Outlier component # 5233
# Outlier component # 5234
# Outlier component # 5235
# Outlier component # 5236
# Outlier component # 5237
# Outlier component # 5238
# Outlier component # 5239
# Outlier component # 5240
# Outlier component # 5241
# Outlier component # 5242
# Outlier component # 5243
# Outlier component # 5244
# Outlier component # 5245
# Outlier component # 5246
# Outlier component # 5247
# Outlier component # 5248
# Outlier component # 5249
# Outlier component # 5250
# Outlier component # 5251
# Outlier component # 5252
# Outlier component # 5253
# Outlier component # 5254
# Outlier component # 5255
# Outlier component # 5256
# Outlier component # 5257
# Outlier component # 5258
# Outlier component # 5259
# Outlier component # 5260
# Outlier component # 5261
# Outlier component # 5262
# Outlier component # 5263
# Outlier component # 5264
# Outlier component # 5265
# Outlier component # 5266
# Outlier component # 5267
# Outlier component # 5268
# Outlier component # 5269
# Outlier component # 5270
# Outlier component # 5271
# Outlier component # 5272
# Outlier component # 5273
# Outlier component # 5274
# Outlier component # 5275
# Outlier component # 5276
# Outlier component # 5277
# Outlier component # 5279
# Outlier component # 5280
# Outlier component # 5281
# Outlier component # 5282
# Outlier component # 5284
# Outlier component # 5285
# Outlier component # 5286
# Outlier component # 5288
# Outlier component # 5290
# Outlier component # 5291
# Outlier component # 5292
# Outlier component # 5293
# Outlier component # 5294
# Outlier component # 5299
# Outlier component # 5301
# Outlier component # 5360
# Outlier component # 6109
# Outlier component # 6119
# Outlier component # 6132
# Outlier component # 6133
# Outlier component # 6225
# Outlier component # 6511
# Outlier component # 6523
# Outlier component # 6534
# Outlier component # 6536
# Outlier component # 6537
# Outlier component # 6542
# Outlier component # 6543
# Outlier component # 6544
# Outlier component # 6545
# Outlier component # 6546
# Outlier component # 6548
# Outlier component # 6550
# Outlier component # 6551
# Outlier component # 6552
# Outlier component # 6556
# Outlier component # 6557
# Outlier component # 6558
# Outlier component # 6563
# Outlier component # 6567
# Outlier component # 6568
# Outlier component # 6569
# Outlier component # 6571
# Outlier component # 6572
# Outlier component # 6579
# Outlier component # 6581
# Outlier component # 6600
# Outlier component # 6607
# Outlier component # 6608
# Outlier component # 6609
# Outlier component # 6610
# Outlier component # 6611
# Outlier component # 6613
# Outlier component # 6614
# Outlier component # 6615
# Outlier component # 6618
# Outlier component # 6621
# Outlier component # 6642
# Outlier component # 6653
# Outlier component # 6663
# Outlier component # 6664
# Outlier component # 7518
# Outlier component # 7519
# Outlier component # 7532
# Outlier component # 7538
# Outlier component # 7539
# Outlier component # 7540
# Outlier component # 7541
# Outlier component # 7542
# Outlier component # 7543
# Outlier component # 7544
# Outlier component # 7564
# Outlier component # 7566
# Outlier component # 7567
# Outlier component # 7568
# Outlier component # 7569
# Outlier component # 7570
# Outlier component # 7571
# Outlier component # 7572
# Outlier component # 7575
# Outlier component # 7577
# Outlier component # 7578
# Outlier component # 7581
# Outlier component # 7582
# Outlier component # 7588
# Outlier component # 7590
# Outlier component # 7593
# Outlier component # 7594
# Outlier component # 7597
# Outlier component # 7598
# Outlier component # 7604
# Outlier component # 7606
# Outlier component # 7607
# Outlier component # 7608
# Outlier component # 7609
# Outlier component # 7611
# Outlier component # 7612
# Outlier component # 7613
# Outlier component # 7614
# Outlier component # 7615
# Outlier component # 7616
# Outlier component # 7617
# Outlier component # 7618
# Outlier component # 7619
# Outlier component # 7621
# Outlier component # 7623
# Outlier component # 7624
# Outlier component # 7625
# Outlier component # 7626
# Outlier component # 7627
# Outlier component # 7628
# Outlier component # 7629
# Outlier component # 7630
# Outlier component # 7631
# Outlier component # 7632
# Outlier component # 7633
# Outlier component # 7634
# Outlier component # 7635
# Outlier component # 7636
# Outlier component # 7637
# Outlier component # 7638
# Outlier component # 7639
# Outlier component # 7641
# Outlier component # 7642
# Outlier component # 7643
# Outlier component # 7644
# Outlier component # 7645
# Outlier component # 7646
# Outlier component # 7647
# Outlier component # 7648
# Outlier component # 7649
# Outlier component # 7650
# Outlier component # 7651
# Outlier component # 7652
# Outlier component # 7653
# Outlier component # 7654
# Outlier component # 7655
# Outlier component # 7656
# Outlier component # 7657
# Outlier component # 7658
# Outlier component # 7659
# Outlier component # 7660
# Outlier component # 7661
# Outlier component # 7662
# Outlier component # 7663
# Outlier component # 7664
# Outlier component # 7665
# Outlier component # 7666
# Outlier component # 7667
# Outlier component # 7668
# Outlier component # 7669
# Outlier component # 7670
# Outlier component # 7671
# Outlier component # 7672
# Outlier component # 7673
# Outlier component # 7674
# Outlier component # 7675
# Outlier component # 7676
# Outlier component # 7677
# Outlier component # 7678
# Outlier component # 7679
# Outlier component # 7680
# Outlier component # 7681
# Outlier component # 7682
# Outlier component # 7683
# Outlier component # 7684
# Outlier component # 7685
# Outlier component # 7686
# Outlier component # 7687
# Outlier component # 7688
# Outlier component # 7689
# Outlier component # 7690
# Outlier component # 7691
# Outlier component # 7692
# Outlier component # 7693
# Outlier component # 7694
# Outlier component # 7695
# Outlier component # 7696
# Outlier component # 7697
# Outlier component # 7698
# Outlier component # 7699
# Outlier component # 7700
# Outlier component # 7701
# Outlier component # 7702
# Outlier component # 7703
# Outlier component # 7704
# Outlier component # 7705
# Outlier component # 7706
# Outlier component # 7707
# Outlier component # 7708
# Outlier component # 7709
# Outlier component # 7710
# Outlier component # 7711
# Outlier component # 7712
# Outlier component # 7713
# Outlier component # 7714
# Outlier component # 7715
# Outlier component # 7716
# Outlier component # 7717
# Outlier component # 7718
# Outlier component # 7719
# Outlier component # 7720
# Outlier component # 7721
# Outlier component # 7722
# Outlier component # 7723
# Outlier component # 7724
# Outlier component # 7725
# Outlier component # 7726
# Outlier component # 7727
# Outlier component # 7730
# Outlier component # 7731
# Outlier component # 7732
# Outlier component # 7733
# Outlier component # 7734
# Outlier component # 7735
# Outlier component # 7736
# Outlier component # 7738
# Outlier component # 7739
# Outlier component # 7740
# Outlier component # 7741
# Outlier component # 7742
# Outlier component # 7743
# Outlier component # 7744
# Outlier component # 7745
# Outlier component # 7746
# Outlier component # 7747
# Outlier component # 7748
# Outlier component # 7749
# Outlier component # 7750
# Outlier component # 7751
# Outlier component # 7753
# Outlier component # 7754
# Outlier component # 7755
# Outlier component # 7756
# Outlier component # 7757
# Outlier component # 7759
# Outlier component # 7760
# Outlier component # 7761
# Outlier component # 7763
# Outlier component # 7764
# Outlier component # 7765
# Outlier component # 7767
# Outlier component # 7768
# Outlier component # 7769
# Outlier component # 7770
# Outlier component # 7771
# Outlier component # 7772
# Outlier component # 7773
# Outlier component # 7777
# Outlier component # 7778
# Outlier component # 7779
# Outlier component # 7782
# Outlier component # 7783
# Outlier component # 7784
# Outlier component # 7787
# Outlier component # 7788
# Outlier component # 7791
# Outlier component # 7792
# Outlier component # 7793
# Outlier component # 7794
# Outlier component # 7801
# Outlier component # 7802
# Outlier component # 7803
# Outlier component # 7806
# Outlier component # 7807
# Outlier component # 7808
# Outlier component # 7809
# Outlier component # 7810
# Outlier component # 7811
# Outlier component # 7845
# Outlier component # 7846
# Outlier component # 7847
# Outlier component # 7848
# Outlier component # 7849
# Outlier component # 7852
# Outlier component # 7853
# Outlier component # 7857
# Outlier component # 7859
# Outlier component # 7871
# Outlier component # 7875
# Outlier component # 7876
# Outlier component # 7877
# Outlier component # 7878
# Outlier component # 7879
# Outlier component # 7881
# Outlier component # 7886
# Outlier component # 7887
# Outlier component # 7888
# Outlier component # 7892
# Outlier component # 7893
# Outlier component # 7894
# Outlier component # 7895
# Outlier component # 7896
# Outlier component # 7897
# Outlier component # 7898
# Outlier component # 7899
# Outlier component # 7900
# Outlier component # 7905
# Outlier component # 7906
# Outlier component # 7907
# Outlier component # 7934
# Outlier component # 7935
# Outlier component # 7936
# Outlier component # 7939
# Outlier component # 7940
# Outlier component # 7941
# Outlier component # 7945
# Outlier component # 7973
# Outlier component # 7974
# Outlier component # 7976
# Outlier component # 7990
# Outlier component # 7991
# Outlier component # 7996
# Outlier component # 8002
# Outlier component # 8003
# Outlier component # 8021
# Outlier component # 8045
# Outlier component # 8063
# Outlier component # 8072
# Outlier component # 8073
# Outlier component # 8076
# Outlier component # 8091
# Outlier component # 8093
# Outlier component # 8109
# Outlier component # 8129
# Outlier component # 8131
# Outlier component # 8132
# Outlier component # 8133
# Outlier component # 8134
# Outlier component # 8179
# Outlier component # 8210
# Outlier component # 8211
# Outlier component # 8231
# Outlier component # 9365
# Outlier component # 9373
# Outlier component # 9385
# Outlier component # 9386
# Outlier component # 9392
# Outlier component # 9393
# Outlier component # 9394
# Outlier component # 9395
# Outlier component # 9396
# Outlier component # 9398
# Outlier component # 9399
# Outlier component # 9400
# Outlier component # 9401
# Outlier component # 9402
# Outlier component # 9403
# Outlier component # 9410
# Outlier component # 9411
# Outlier component # 9417
# Outlier component # 9420
# Outlier component # 9423
# Outlier component # 9432
# (50,)
